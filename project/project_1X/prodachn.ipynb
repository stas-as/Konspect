# %%
import pandas as pd

import seaborn as sns
import plotly
import plotly.express as px

# %%
data = pd.read_csv('data/table_matches_1tur.csv')

# %%
data
# Out:
#    Unnamed: 0  id матча       время матча                        погода  \
# 0           0   1736832  06.08.2022 16:30               +14°C\nпасмурно
# 1           1   1736825  05.08.2022 21:35               +18°C\nсолнечно
# 2           2   1736831  06.08.2022 16:30               +15°C\nсолнечно
# 3           3   1736830  06.08.2022 16:30               +15°C\nсолнечно
# 4           4   1736829  06.08.2022 16:30               +20°C\nсолнечно
# 5           5   1736827  06.08.2022 16:30  +17°C\nпеременная облачность
# 6           6   1736826  06.08.2022 19:30               +17°C\nсолнечно
# 7           7   1736833  07.08.2022 16:30  +14°C\nпеременная облачность
# 8           8   1736828  07.08.2022 18:30               +19°C\nсолнечно
#
#              Команда1  Счет 1  Счет 2    Команда2     1     X  ...  Офсайды2  \
# 0            Аугсбург       0       4    Фрайбург  3.68  3.66  ...         2
# 1  Айнтрахт Франкфурт       1       6     Бавария  6.15  5.12  ...         3
# ...

# %%
fig = px.imshow(
    data.corr(),
    text_auto=True,
    height=1200,
    width=1200
)
fig.show()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_14916\3993961649.py:2: FutureWarning:
#
# The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
