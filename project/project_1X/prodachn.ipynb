# %%
import pandas as pd

import seaborn as sns
import plotly
import plotly.express as px

# %%
data = pd.read_csv('data/table_matches_22.csv')

# %%
data
# Out:
#      Unnamed: 0       id                                   общая информация  \
# 0             0  1736825  Бундеслига, 1-й тур, регулярный сезон, 05.08.2...
# 1             1  1736826  Бундеслига, 1-й тур, регулярный сезон, 06.08.2...
# 2             2  1736827  Бундеслига, 1-й тур, регулярный сезон, 06.08.2...
# 3             3  1736828  Бундеслига, 1-й тур, регулярный сезон, 07.08.2...
# 4             4  1736829  Бундеслига, 1-й тур, регулярный сезон, 06.08.2...
# ..          ...      ...                                                ...
# 273         273  1737118  Бундеслига, 33-й тур, регулярный сезон, 21.05....
# 274         274  1737119  Бундеслига, 33-й тур, регулярный сезон, 20.05....
# 275         275  1737120  Бундеслига, 33-й тур, регулярный сезон, 20.05....
# 276         276  1737121  Бундеслига, 33-й тур, регулярный сезон, 20.05....
# 277         277  1737122  Бундеслига, 34-й тур, регулярный сезон, 27.05....
#
# ...

# %%
fig = px.imshow(
    data.corr(),
    text_auto=True,
    height=1200,
    width=1200
)
fig.show()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_15756\3993961649.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr(),

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 278 entries, 0 to 277
# Data columns (total 61 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           278 non-null    int64
#  1   id                   278 non-null    int64
#  2   общая информация     278 non-null    object
#  3   Дата                 278 non-null    object
#  4   Команда1             278 non-null    object
#  5   счет1                278 non-null    int64
#  6   Команда2             278 non-null    object
#  7   счет2                278 non-null    int64
#  8   xG1                  278 non-null    float64
#  9   xG2                  278 non-null    float64
#  10  Удары1               278 non-null    float64
#  11  Удары2               278 non-null    float64
#  12  Удары в створ1       278 non-null    float64
#  13  Удары в створ2       278 non-null    float64
#  14  Сейвы1               278 non-null    float64
# ...
