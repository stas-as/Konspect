# %%
import pandas as pd
import urllib.parse as req
import requests
from bs4 import BeautifulSoup

# %%
url_tur_table = 'https://soccer365.ru/competitions/17/'
url_result_table = 'https://soccer365.ru/competitions/17/results/'
url_math_table = 'https://soccer365.ru/games/1736826/'

# %%
tables_tur = pd.read_html(url_tur_table)
tables_tur[0].to_csv('data/tur_table.csv')

# %%
path_common = req.urlparse('https://soccer365.ru/competitions/17/')
url = path_common.scheme + '://' + req.quote(path_common.netloc) +  req.quote(path_common.path) + '#'+ req.quote(path_common.fragment)
tables_result = pd.read_html(url)

# %%
#результаты
a = '''xG
0.79   1.57
Удары
16   13
Удары в створ
3   6
Сейвы
4   2
Владение %
61   39
Угловые
3   5
Нарушения
11   16
Офсайды
1   1
Желтые карточки
2   3
Красные карточки
0   0
Атаки
140   86
Опасные атаки
36   29
Передачи
509   325
Точность передач %
83   71
Штрафные удары
14   13
Вбрасывания
18   27
Навесы
24   19'''
#название команд
b = '''06.08.2022 16:30
Бохум

1
2

Майнц'''
#Коэфиценты
c = """3.473.472.202.001.90"""
# id матча
e1 = """5	15	3.0	4	0	1
матчи	голы	за матч	победы	ничьи	поражения
30.07.22, 14:01"""

e2 = """5	9	1.8	3	1	1
матчи	голы	за матч	победы	ничьи	поражения
31.07.22, 19:01"""
d = 1736831
#погода
p = """+15°C
солнечно"""

# %%
def result_math(a,b,c,d,e1,e2,p):
    lister = a.split()
    lister2 = b.split()
    lister_def = e1.split()
    lister_ofe = e2.split()
    dicter = dict({
        'id матча':[],
        'время матча':[],
        'погода':[],
        'Команда1': [],
        'Счет 1': [],
        'Счет 2': [],
        'Команда2': [],
        '1':[],
        'X':[],
        '2':[],
        'ТМ 2.5':[],
        'ТБ 2.5':[],
        'голы 1':[],
        'победы 1':[],
        'ничьи 1':[],
        'поражения 1':[],
        'время прошлого матча 1':[],
        'голы 2':[],
        'победы 2':[],
        'ничьи 2':[],
        'поражения 2':[],
        'время прошлого матча 2':[],
        'xG1': [],
        'Удары1': [],
        'Удары в створ1': [],
        'Сейвы1': [],
        'Владение %1': [],
        'Угловые1': [],
        'Нарушения1': [],
        'Офсайды1': [],
        'Желтые карточки1': [],
        'Красные карточки1': [],
        'Атаки1': [],
        'Опасные атаки1': [],
        'Передачи1': [],
        'Точность передач %1': [],
        'Штрафные удары1': [],
        'Вбрасывания1': [],
        'Навесы1': [],
        'xG2': [],
        'Удары2': [],
        'Удары в створ2': [],
        'Сейвы2': [],
        'Владение %2': [],
        'Угловые2': [],
        'Нарушения2': [],
        'Офсайды2': [],
        'Желтые карточки2': [],
        'Красные карточки2': [],
        'Атаки2': [],
        'Опасные атаки2': [],
        'Передачи2': [],
        'Точность передач %2': [],
        'Штрафные удары2': [],
        'Вбрасывания2': [],
        'Навесы2': [],
    })
    dicter['id матча'] = d
    dicter['время матча'] = b[:16]
    dicter['погода'] = p
    dicter['1'] = c[0:4]
    dicter['X'] = c[4:8]
    dicter['2'] = c[8:12]
    dicter['ТМ 2.5'] = c[12:16]
    dicter['ТБ 2.5'] = c[16:]
    dicter['голы 1'] = lister_def[1]
    dicter['победы 1'] = lister_def[3]
    dicter['ничьи 1'] = lister_def[4]
    dicter['поражения 1'] = lister_def[5]
    dicter['время прошлого матча 1'] = e1[-15:]
    dicter['голы 2'] = lister_ofe[1]
    dicter['победы 2'] = lister_ofe[3]
    dicter['ничьи 2'] =lister_ofe[4]
    dicter['поражения 2'] = lister_ofe[5]
    dicter['время прошлого матча 2'] = e2[-15:]
    if len(lister2) == 6:
        dicter['Команда1'] = lister2[2]#
        dicter['Счет 1'] = lister2[3]
        dicter['Счет 2'] = lister2[4]
        dicter['Команда2'] = lister2[5]
    elif len(lister2) == 8:
        dicter['Команда1'] = lister2[2] + ' ' + lister2[3]
        dicter['Счет 1'] = lister2[4]
        dicter['Счет 2'] = lister2[5]
        dicter['Команда2'] = lister2[6] + ' ' + lister2[8]
    elif len(lister2) == 7:
        if len(lister2[3]) > 2:
            dicter['Команда1'] = lister2[2] + ' ' + lister2[3]
            dicter['Счет 1'] = lister2[4]
            dicter['Счет 2'] = lister2[5]
            dicter['Команда2'] = lister2[6]
        else:
            dicter['Команда1'] = lister2[2]#
            dicter['Счет 1'] = lister2[3]
            dicter['Счет 2'] = lister2[4]
            dicter['Команда2'] = lister2[5] + ' ' + lister2[6]
    dicter['xG1'] = lister[1]
    dicter['Удары1'] = lister[4]
    dicter['Удары в створ1'] = lister[9]
    dicter['Сейвы1'] = lister[12]
    dicter['Владение %1'] = lister[16]
    dicter['Угловые1'] = lister[19]
    dicter['Нарушения1'] = lister[22]
    dicter['Офсайды1'] = lister[25]
    dicter['Желтые карточки1'] = lister[29]
    dicter['Красные карточки1'] = lister[33]
    dicter['Атаки1'] = lister[36]
    dicter['Опасные атаки1'] = lister[40]
    dicter['Передачи1'] = lister[43]
    dicter['Точность передач %1'] = lister[48]
    dicter['Штрафные удары1'] = lister[52]
    dicter['Вбрасывания1'] = lister[55]
    dicter['Навесы1'] = lister[58]
    dicter['xG2'] = lister[2]
    dicter['Удары2'] = lister[5]
    dicter['Удары в створ2'] = lister[10]
    dicter['Сейвы2'] = lister[13]
    dicter['Владение %2'] = lister[17]
    dicter['Угловые2'] = lister[20]
    dicter['Нарушения2'] = lister[23]
    dicter['Офсайды2'] = lister[26]
    dicter['Желтые карточки2'] = lister[30]
    dicter['Красные карточки2'] = lister[34]
    dicter['Атаки2'] = lister[37]
    dicter['Опасные атаки2'] = lister[41]
    dicter['Передачи2'] = lister[44]
    dicter['Точность передач %2'] = lister[49]
    dicter['Штрафные удары2'] = lister[53]
    dicter['Вбрасывания2'] = lister[56]
    dicter['Навесы2'] = lister[59]
    return dicter

# %%
df1 = result_math(a,b,c,d,e1,e2,p)
df1 = pd.Series(df1)

# %%
df1
# Out:
# id матча                           1736831
# время матча               06.08.2022 16:30
# погода                     +15°C\nсолнечно
# Команда1                             Бохум
# Счет 1                                   1
# Счет 2                                   2
# Команда2                             Майнц
# 1                                     3.47
# X                                     3.47
# 2                                     2.20
# ТМ 2.5                                2.00
# ТБ 2.5                                1.90
# голы 1                                  15
# победы 1                                 4
# ничьи 1                                  0
# поражения 1                              1
# время прошлого матча 1     30.07.22, 14:01
# голы 2                                   9
# победы 2                                 3
# ничьи 2                                  1
# поражения 2                              1
# время прошлого матча 2     31.07.22, 19:01
# xG1                                   0.79
# Удары1                                  16
# Удары в створ1                           3
# Сейвы1                                   4
# Владение %1                             61
# Угловые1                                 3
# Нарушения1                              11
# Офсайды1                                 1
# Желтые карточки1                         2
# Красные карточки1                        0
# Атаки1                                 140
# Опасные атаки1                          36
# Передачи1                              509
# Точность передач %1                     83
# Штрафные удары1                         14
# Вбрасывания1                            18
# Навесы1                                 24
# xG2                                   1.57
# Удары2                                  13
# Удары в створ2                           6
# Сейвы2                                   2
# Владение %2                             39
# Угловые2                                 5
# Нарушения2                              16
# Офсайды2                                 1
# Желтые карточки2                         3
# Красные карточки2                        0
# Атаки2                                  86
# Опасные атаки2                          29
# Передачи2                              325
# Точность передач %2                     71
# Штрафные удары2                         13
# Вбрасывания2                            27
# Навесы2                                 19
# dtype: object

# %%
lister_match1 = list(df1)
lister_match1
# Out:
# [1736831,
#  '06.08.2022 16:30',
#  '+15°C\nсолнечно',
#  'Бохум',
#  '1',
#  '2',
#  'Майнц',
#  '3.47',
#  '3.47',
#  '2.20',
#  '2.00',
#  '1.90',
#  '15',
#  '4',
#  '0',
#  '1',
#  '30.07.22, 14:01',
#  '9',
#  '3',
#  '1',
#  '1',
#  '31.07.22, 19:01',
#  '0.79',
#  '16',
#  '3',
#  '4',
#  '61',
#  '3',
#  '11',
#  '1',
#  '2',
#  '0',
#  '140',
#  '36',
#  '509',
#  '83',
#  '14',
#  '18',
#  '24',
#  '1.57',
#  '13',
#  '6',
#  '2',
#  '39',
#  '5',
#  '16',
#  '1',
#  '3',
#  '0',
#  '86',
#  '29',
#  '325',
#  '71',
#  '13',
#  '27',
#  '19']

# %%
colomunus = ['id матча','время матча','погода','Команда1','Счет 1','Счет 2','Команда2','1','X','2','ТМ 2.5','ТБ 2.5','голы 1','победы 1','ничьи 1','поражения 1','время прошлого матча 1','голы 2','победы 2','ничьи 2','поражения 2','время прошлого матча 2','xG1','Удары1','Удары в створ1','Сейвы1','Владение %1','Угловые1','Нарушения1','Офсайды1','Желтые карточки1','Красные карточки1','Атаки1','Опасные атаки1','Передачи1','Точность передач %1','Штрафные удары1','Вбрасывания1','Навесы1','xG2','Удары2','Удары в створ2','Сейвы2','Владение %2','Угловые2','Нарушения2','Офсайды2','Желтые карточки2','Красные карточки2','Атаки2','Опасные атаки2','Передачи2','Точность передач %2','Штрафные удары2','Вбрасывания2','Навесы2']

# %%
data = pd.read_csv('data/table_matches.csv')

# %%
data = data.drop(columns=['Unnamed: 0.1','Unnamed: 0'])

# %%
data
# Out:
#    id матча       время матча           погода            Команда1  Счет 1  \
# 0   1736832  06.08.2022 16:30  +14°C\nпасмурно            Аугсбург       0
# 1   1736825  05.08.2022 21:35  +18°C\nсолнечно  Айнтрахт Франкфурт       1
#
#    Счет 2  Команда2     1     X     2  ...  Офсайды2  Желтые карточки2  \
# 0       4  Фрайбург  3.68  3.66  2.05  ...         2                 0
# 1       6   Бавария  6.15  5.12  1.49  ...         3                 0
#
#    Красные карточки2  Атаки2  Опасные атаки2  Передачи2 Точность передач %2  \
# 0                  0     102              51        290                  78
# 1                  0     134              46        637                  88
#
#    Штрафные удары2  Вбрасывания2  Навесы2
# 0               12            20       15
# 1               15             9       14
#
# [2 rows x 56 columns]

# %%
data.loc[ len(data)] = lister_match1

# %%
data
# Out:
#    id матча       время матча           погода            Команда1 Счет 1  \
# 0   1736832  06.08.2022 16:30  +14°C\nпасмурно            Аугсбург      0
# 1   1736825  05.08.2022 21:35  +18°C\nсолнечно  Айнтрахт Франкфурт      1
# 2   1736831  06.08.2022 16:30  +15°C\nсолнечно               Бохум      1
#
#   Счет 2  Команда2     1     X     2  ... Офсайды2 Желтые карточки2  \
# 0      4  Фрайбург  3.68  3.66  2.05  ...        2                0
# 1      6   Бавария  6.15  5.12  1.49  ...        3                0
# 2      2     Майнц  3.47  3.47  2.20  ...        1                3
#
#   Красные карточки2 Атаки2 Опасные атаки2 Передачи2 Точность передач %2  \
# 0                 0    102             51       290                  78
# 1                 0    134             46       637                  88
# 2                 0     86             29       325                  71
#
#   Штрафные удары2 Вбрасывания2 Навесы2
# 0              12           20      15
# 1              15            9      14
# 2              13           27      19
#
# [3 rows x 56 columns]
