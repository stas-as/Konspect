# %%
import pandas as pd
import urllib.parse as req
import requests
from bs4 import BeautifulSoup

# %%
url_tur_table = 'https://soccer365.ru/competitions/17/'
url_result_table = 'https://soccer365.ru/competitions/17/results/'
url_math_table = 'https://soccer365.ru/games/1736826/'

# %%
tables_tur = pd.read_html(url_tur_table)
tables_tur[0].to_csv('data/tur_table.csv')

# %%
path_common = req.urlparse('https://soccer365.ru/competitions/17/')
url = path_common.scheme + '://' + req.quote(path_common.netloc) +  req.quote(path_common.path) + '#'+ req.quote(path_common.fragment)
tables_result = pd.read_html(url)

# %%
#результаты
a = '''xG
4.6   0.38
Удары
30   6
Удары в створ
10   2
Сейвы
1   7
Владение %
73   27
Угловые
9   1
Нарушения
8   10
Офсайды
2   1
Желтые карточки
0   1
Красные карточки
0   1
Атаки
116   75
Опасные атаки
88   15
Передачи
598   199
Точность передач %
89   65
Штрафные удары
9   9
Вбрасывания
24   13
Навесы
38   7'''
#название команд
b = '''07.08.2022 18:30
Кёльн

3
1

Шальке'''
#погода
p = """+19°C
солнечно"""
#Коэфиценты
c = """1.973.843.792.101.82"""
# id матча
e1 = """5	11	2.2	2	1	2
матчи	голы	за матч	победы	ничьи	поражения
30.07.22, 16:31"""

e2 = """5	12	2.4	2	2	1
матчи	голы	за матч	победы	ничьи	поражения
31.07.22, 14:01"""
d = 1736828

# %%
def result_math(a,b,c,d,e1,e2,p):
    lister = a.split()
    lister2 = b.split()
    lister_def = e1.split()
    lister_ofe = e2.split()
    dicter = dict({
        'id матча':[],
        'время матча':[],
        'погода':[],
        'Команда1': [],
        'Счет 1': [],
        'Счет 2': [],
        'Команда2': [],
        '1':[],
        'X':[],
        '2':[],
        'ТМ 2.5':[],
        'ТБ 2.5':[],
        'голы 1':[],
        'победы 1':[],
        'ничьи 1':[],
        'поражения 1':[],
        'время прошлого матча 1':[],
        'голы 2':[],
        'победы 2':[],
        'ничьи 2':[],
        'поражения 2':[],
        'время прошлого матча 2':[],
        'xG1': [],
        'Удары1': [],
        'Удары в створ1': [],
        'Сейвы1': [],
        'Владение %1': [],
        'Угловые1': [],
        'Нарушения1': [],
        'Офсайды1': [],
        'Желтые карточки1': [],
        'Красные карточки1': [],
        'Атаки1': [],
        'Опасные атаки1': [],
        'Передачи1': [],
        'Точность передач %1': [],
        'Штрафные удары1': [],
        'Вбрасывания1': [],
        'Навесы1': [],
        'xG2': [],
        'Удары2': [],
        'Удары в створ2': [],
        'Сейвы2': [],
        'Владение %2': [],
        'Угловые2': [],
        'Нарушения2': [],
        'Офсайды2': [],
        'Желтые карточки2': [],
        'Красные карточки2': [],
        'Атаки2': [],
        'Опасные атаки2': [],
        'Передачи2': [],
        'Точность передач %2': [],
        'Штрафные удары2': [],
        'Вбрасывания2': [],
        'Навесы2': [],
    })
    dicter['id матча'] = d
    dicter['время матча'] = b[:16]
    dicter['погода'] = p
    dicter['1'] = c[0:4]
    dicter['X'] = c[4:8]
    dicter['2'] = c[8:12]
    dicter['ТМ 2.5'] = c[12:16]
    dicter['ТБ 2.5'] = c[16:]
    dicter['голы 1'] = lister_def[1]
    dicter['победы 1'] = lister_def[3]
    dicter['ничьи 1'] = lister_def[4]
    dicter['поражения 1'] = lister_def[5]
    dicter['время прошлого матча 1'] = e1[-15:]
    dicter['голы 2'] = lister_ofe[1]
    dicter['победы 2'] = lister_ofe[3]
    dicter['ничьи 2'] =lister_ofe[4]
    dicter['поражения 2'] = lister_ofe[5]
    dicter['время прошлого матча 2'] = e2[-15:]
    if len(lister2) == 6:
        dicter['Команда1'] = lister2[2]#
        dicter['Счет 1'] = lister2[3]
        dicter['Счет 2'] = lister2[4]
        dicter['Команда2'] = lister2[5]
    elif len(lister2) == 8:
        dicter['Команда1'] = lister2[2] + ' ' + lister2[3]
        dicter['Счет 1'] = lister2[4]
        dicter['Счет 2'] = lister2[5]
        dicter['Команда2'] = lister2[6] + ' ' + lister2[8]
    elif len(lister2) == 7:
        if len(lister2[3]) > 2 or lister2[3] == 'М' :
            dicter['Команда1'] = lister2[2] + ' ' + lister2[3]
            dicter['Счет 1'] = lister2[4]
            dicter['Счет 2'] = lister2[5]
            dicter['Команда2'] = lister2[6]
        else:
            dicter['Команда1'] = lister2[2]#
            dicter['Счет 1'] = lister2[3]
            dicter['Счет 2'] = lister2[4]
            dicter['Команда2'] = lister2[5] + ' ' + lister2[6]
    dicter['xG1'] = lister[1]
    dicter['Удары1'] = lister[4]
    dicter['Удары в створ1'] = lister[9]
    dicter['Сейвы1'] = lister[12]
    dicter['Владение %1'] = lister[16]
    dicter['Угловые1'] = lister[19]
    dicter['Нарушения1'] = lister[22]
    dicter['Офсайды1'] = lister[25]
    dicter['Желтые карточки1'] = lister[29]
    dicter['Красные карточки1'] = lister[33]
    dicter['Атаки1'] = lister[36]
    dicter['Опасные атаки1'] = lister[40]
    dicter['Передачи1'] = lister[43]
    dicter['Точность передач %1'] = lister[48]
    dicter['Штрафные удары1'] = lister[52]
    dicter['Вбрасывания1'] = lister[55]
    dicter['Навесы1'] = lister[58]
    dicter['xG2'] = lister[2]
    dicter['Удары2'] = lister[5]
    dicter['Удары в створ2'] = lister[10]
    dicter['Сейвы2'] = lister[13]
    dicter['Владение %2'] = lister[17]
    dicter['Угловые2'] = lister[20]
    dicter['Нарушения2'] = lister[23]
    dicter['Офсайды2'] = lister[26]
    dicter['Желтые карточки2'] = lister[30]
    dicter['Красные карточки2'] = lister[34]
    dicter['Атаки2'] = lister[37]
    dicter['Опасные атаки2'] = lister[41]
    dicter['Передачи2'] = lister[44]
    dicter['Точность передач %2'] = lister[49]
    dicter['Штрафные удары2'] = lister[53]
    dicter['Вбрасывания2'] = lister[56]
    dicter['Навесы2'] = lister[59]
    return dicter

# %%
df1 = result_math(a,b,c,d,e1,e2,p)
df1 = pd.Series(df1)

# %%
df1
# Out:
# id матча                           1736828
# время матча               07.08.2022 18:30
# погода                     +19°C\nсолнечно
# Команда1                             Кёльн
# Счет 1                                   3
# Счет 2                                   1
# Команда2                            Шальке
# 1                                     1.97
# X                                     3.84
# 2                                     3.79
# ТМ 2.5                                2.10
# ТБ 2.5                                1.82
# голы 1                                  11
# победы 1                                 2
# ничьи 1                                  1
# поражения 1                              2
# время прошлого матча 1     30.07.22, 16:31
# голы 2                                  12
# победы 2                                 2
# ничьи 2                                  2
# поражения 2                              1
# время прошлого матча 2     31.07.22, 14:01
# xG1                                    4.6
# Удары1                                  30
# Удары в створ1                          10
# Сейвы1                                   1
# Владение %1                             73
# Угловые1                                 9
# Нарушения1                               8
# Офсайды1                                 2
# Желтые карточки1                         0
# Красные карточки1                        0
# Атаки1                                 116
# Опасные атаки1                          88
# Передачи1                              598
# Точность передач %1                     89
# Штрафные удары1                          9
# Вбрасывания1                            24
# Навесы1                                 38
# xG2                                   0.38
# Удары2                                   6
# Удары в створ2                           2
# Сейвы2                                   7
# Владение %2                             27
# Угловые2                                 1
# Нарушения2                              10
# Офсайды2                                 1
# Желтые карточки2                         1
# Красные карточки2                        1
# Атаки2                                  75
# Опасные атаки2                          15
# Передачи2                              199
# Точность передач %2                     65
# Штрафные удары2                          9
# Вбрасывания2                            13
# Навесы2                                  7
# dtype: object

# %%
lister_match1 = list(df1)
lister_match1
# Out:
# [1736828,
#  '07.08.2022 18:30',
#  '+19°C\nсолнечно',
#  'Кёльн',
#  '3',
#  '1',
#  'Шальке',
#  '1.97',
#  '3.84',
#  '3.79',
#  '2.10',
#  '1.82',
#  '11',
#  '2',
#  '1',
#  '2',
#  '30.07.22, 16:31',
#  '12',
#  '2',
#  '2',
#  '1',
#  '31.07.22, 14:01',
#  '4.6',
#  '30',
#  '10',
#  '1',
#  '73',
#  '9',
#  '8',
#  '2',
#  '0',
#  '0',
#  '116',
#  '88',
#  '598',
#  '89',
#  '9',
#  '24',
#  '38',
#  '0.38',
#  '6',
#  '2',
#  '7',
#  '27',
#  '1',
#  '10',
#  '1',
#  '1',
#  '1',
#  '75',
#  '15',
#  '199',
#  '65',
#  '9',
#  '13',
#  '7']

# %%
colomunus = ['id матча','время матча','погода','Команда1','Счет 1','Счет 2','Команда2','1','X','2','ТМ 2.5','ТБ 2.5','голы 1','победы 1','ничьи 1','поражения 1','время прошлого матча 1','голы 2','победы 2','ничьи 2','поражения 2','время прошлого матча 2','xG1','Удары1','Удары в створ1','Сейвы1','Владение %1','Угловые1','Нарушения1','Офсайды1','Желтые карточки1','Красные карточки1','Атаки1','Опасные атаки1','Передачи1','Точность передач %1','Штрафные удары1','Вбрасывания1','Навесы1','xG2','Удары2','Удары в створ2','Сейвы2','Владение %2','Угловые2','Нарушения2','Офсайды2','Желтые карточки2','Красные карточки2','Атаки2','Опасные атаки2','Передачи2','Точность передач %2','Штрафные удары2','Вбрасывания2','Навесы2']

# %%
data = pd.read_csv('data/table_matches.csv')

# %%
data = data.drop(columns=['Unnamed: 0'])

# %%
data
# Out:
#    id матча       время матча                        погода  \
# 0   1736832  06.08.2022 16:30               +14°C\nпасмурно
# 1   1736825  05.08.2022 21:35               +18°C\nсолнечно
# 2   1736831  06.08.2022 16:30               +15°C\nсолнечно
# 3   1736830  06.08.2022 16:30               +15°C\nсолнечно
# 4   1736829  06.08.2022 16:30               +20°C\nсолнечно
# 5   1736827  06.08.2022 16:30  +17°C\nпеременная облачность
# 6   1736826  06.08.2022 19:30               +17°C\nсолнечно
# 7   1736833  07.08.2022 16:30  +14°C\nпеременная облачность
#
#              Команда1  Счет 1  Счет 2    Команда2     1     X     2  ...  \
# 0            Аугсбург       0       4    Фрайбург  3.68  3.66  2.05  ...
# 1  Айнтрахт Франкфурт       1       6     Бавария  6.15  5.12  1.49  ...
# 2               Бохум       1       2       Майнц  3.47  3.47  2.20  ...
# 3          Вольфсбург       2       2      Вердер  2.04  3.70  3.71  ...
# 4          Боруссия М       3       1  Хоффенхайм  1.99  4.12  3.51  ...
# 5        Унион Берлин       3       1       Герта  1.90  3.69  4.30  ...
# 6   Боруссия Дортмунд       1       0       Байер  1.98  4.20  3.49  ...
# 7            Штутгарт       1       1  РБ Лейпциг  3.96  3.92  1.91  ...
#
#    Офсайды2  Желтые карточки2  Красные карточки2  Атаки2  Опасные атаки2  \
# 0         2                 0                  0     102              51
# 1         3                 0                  0     134              46
# 2         1                 3                  0      86              29
# 3         4                 2                  0     108              31
# 4         2                 4                  1      68              22
# 5         1                 3                  0      39               9
# 6         4                 4                  1     134              40
# 7         2                 1                  0     140              75
#
#    Передачи2 Точность передач %2  Штрафные удары2  Вбрасывания2  Навесы2
# 0        290                  78               12            20       15
# 1        637                  88               15             9       14
# 2        325                  71               13            27       19
# 3        334                  70               11            17       12
# 4        377                  79               16            11        9
# 5        378                  79               22            26       16
# 6        477                  83               14            24       15
# 7        541                  88               11            21       29
#
# [8 rows x 56 columns]

# %%
data.loc[len(data)] = lister_match1

# %%
data
# Out:
#    id матча       время матча                        погода  \
# 0   1736832  06.08.2022 16:30               +14°C\nпасмурно
# 1   1736825  05.08.2022 21:35               +18°C\nсолнечно
# 2   1736831  06.08.2022 16:30               +15°C\nсолнечно
# 3   1736830  06.08.2022 16:30               +15°C\nсолнечно
# 4   1736829  06.08.2022 16:30               +20°C\nсолнечно
# 5   1736827  06.08.2022 16:30  +17°C\nпеременная облачность
# 6   1736826  06.08.2022 19:30               +17°C\nсолнечно
# 7   1736833  07.08.2022 16:30  +14°C\nпеременная облачность
# 8   1736828  07.08.2022 18:30               +19°C\nсолнечно
#
#              Команда1 Счет 1 Счет 2    Команда2     1     X     2  ...  \
# 0            Аугсбург      0      4    Фрайбург  3.68  3.66  2.05  ...
# 1  Айнтрахт Франкфурт      1      6     Бавария  6.15  5.12  1.49  ...
# 2               Бохум      1      2       Майнц  3.47  3.47   2.2  ...
# 3          Вольфсбург      2      2      Вердер  2.04   3.7  3.71  ...
# 4          Боруссия М      3      1  Хоффенхайм  1.99  4.12  3.51  ...
# 5        Унион Берлин      3      1       Герта   1.9  3.69   4.3  ...
# 6   Боруссия Дортмунд      1      0       Байер  1.98   4.2  3.49  ...
# 7            Штутгарт      1      1  РБ Лейпциг  3.96  3.92  1.91  ...
# 8               Кёльн      3      1      Шальке  1.97  3.84  3.79  ...
#
#   Офсайды2 Желтые карточки2 Красные карточки2 Атаки2 Опасные атаки2 Передачи2  \
# 0        2                0                 0    102             51       290
# 1        3                0                 0    134             46       637
# 2        1                3                 0     86             29       325
# 3        4                2                 0    108             31       334
# 4        2                4                 1     68             22       377
# 5        1                3                 0     39              9       378
# 6        4                4                 1    134             40       477
# 7        2                1                 0    140             75       541
# 8        1                1                 1     75             15       199
#
#   Точность передач %2 Штрафные удары2 Вбрасывания2 Навесы2
# 0                  78              12           20      15
# 1                  88              15            9      14
# 2                  71              13           27      19
# 3                  70              11           17      12
# 4                  79              16           11       9
# 5                  79              22           26      16
# 6                  83              14           24      15
# 7                  88              11           21      29
# 8                  65               9           13       7
#
# [9 rows x 56 columns]

# %%
#data.to_csv('data/table_matches.csv')
